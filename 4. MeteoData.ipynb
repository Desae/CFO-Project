# %% [markdown]
# ## Documentation on GET Requests of the MeteoData Folder
#
# ### Description
# Requests for retrieving weather observation data from the KNMI meteostations.

# %%
import requests 

headers = {
    'token': "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3N1ZWR0byI6ImFzZWRhLm9hZEBnbWFpbC5jb20iLCJyZXNvdXJjZSI6WyIqIl0sInJlcXVlc3RfbGltaXQiOjI1MDAwLCJhcmVhX2xpbWl0IjoxLjBFOCwiZXhwIjoxNTQ4ODg5MjAwLCJpYXQiOjE1Mzg1ODY4NzAsImlzc3VlZGRhdGUiOjE1Mzg1ODY4NzB9.x6R7G35nCpwLbBwQ6XHuuJkn-37WIpaxNvDhEu4nTr4"
    }

def getData(url):
    data = requests.get(url, headers=headers)
    return data.json()

# %% [markdown]
# ### 1. Retrieve weather data from one of the meteostations for a specified time period.  Dates can be entered as yyyymmdd, yyyymm, or yyyy (meteostation '356', fromdate '2016' and todate '2017' are used in this example).

# %%
getData("http://agrodatacube.wur.nl/api/v1/rest/meteodata?output_epsg=28992&meteostation=356&fromdate=2016&todate=2017&page_size=25&page_offset=0")
# Out:
# {'features': [{'geometry': {'coordinates': [138384.096644208,
#      430076.049523134],
#     'type': 'Point'},
#    'properties': {'datum': '2016-01-01',
#     'global_radiation': 247.0,
#     'max_humidity': 100.0,
#     'max_temperature': 7.7,
#     'mean_daily_cloud_cover': 5.0,
#     'mean_humidity': 96.0,
#     'mean_sea_level_pressure': 1021.8,
#     'mean_temperature': 4.6,
#     'meteostationid': 356,
#     'min_temperature': 0.9,
#     'potential_evapotranspiration': 0.3,
#     'precipitation': 0.0,
#     'sunshine_duration': 2.3},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [138384.096644208, 430076.049523134],
#     'type': 'Point'},
#    'properties': {'datum': '2016-01-02',
#     'global_radiation': 140.0,
#     'max_humidity': 97.0,
#     'max_temperature': 7.0,
#     'mean_daily_cloud_cover': 8.0,
#     'mean_humidity': 92.0,
#     'mean_sea_level_pressure': 1008.7,
#     'mean_temperature': 5.9,
#     'meteostationid': 356,
# ...

# %% [markdown]
# ### 2. Retrieve weather data from one of the meteostations and for a specific date.  The date can be entered as yyyymmdd, yyyymm, or yyyy (date '2016' is used in this example).

# %%
getData("http://agrodatacube.wur.nl/api/v1/rest/meteodata/356/2016?page_size=25&page_offset=0")
# Out:
# {'features': [{'geometry': None,
#    'properties': {'datum': '2016-01-01',
#     'global_radiation': 247.0,
#     'max_humidity': 100.0,
#     'max_temperature': 7.7,
#     'mean_daily_cloud_cover': 5.0,
#     'mean_humidity': 96.0,
#     'mean_sea_level_pressure': 1021.8,
#     'mean_temperature': 4.6,
#     'meteostationid': 356,
#     'min_temperature': 0.9,
#     'potential_evapotranspiration': 0.3,
#     'precipitation': 0.0,
#     'sunshine_duration': 2.3},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'datum': '2016-01-02',
#     'global_radiation': 140.0,
#     'max_humidity': 97.0,
#     'max_temperature': 7.0,
#     'mean_daily_cloud_cover': 8.0,
#     'mean_humidity': 92.0,
#     'mean_sea_level_pressure': 1008.7,
#     'mean_temperature': 5.9,
#     'meteostationid': 356,
#     'min_temperature': 4.7,
#     'potential_evapotranspiration': 0.2,
#     'precipitation': 3.5,
#     'sunshine_duration': 1.5},
#    'type': 'Feature'},
# ...
