# %% [markdown]
# ## Documentation on GET Requests of the MeteoStations Folder
#
# ### Description

# %% [markdown]
# Requests to retrieve information about the KNMI (the Royal Netherlands Meteorological Institute) weather stations for which data has been stored in the Cube. This data is provided as Open Data by KNMI, see: https://data.knmi.nl/.
#
# Once the ID of a meteostation has been retrieved it can be used to request further details and the weather observations of that particular station.

# %%
import requests
import pandas as pd
import numpy as np
headers = {
    'token': "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3N1ZWR0byI6ImFzZWRhLm9hZEBnbWFpbC5jb20iLCJyZXNvdXJjZSI6WyIqIl0sInJlcXVlc3RfbGltaXQiOjI1MDAwLCJhcmVhX2xpbWl0IjoxLjBFOCwiZXhwIjoxNTQ4ODg5MjAwLCJpYXQiOjE1Mzg1ODY4NzAsImlzc3VlZGRhdGUiOjE1Mzg1ODY4NzB9.x6R7G35nCpwLbBwQ6XHuuJkn-37WIpaxNvDhEu4nTr4"
    }

# %% [markdown]
# **_First request Returns a list of all meteostations for which data is available._**

# %% [markdown]
# #### Content of this endpoint:
# * coordinates
# * meteostationid
# * name
# * longitude
# * latitude
# * altitude
# * source
# * wmocode
# * provider

# %%
def getData(url):
    data = requests.get(url, headers=headers)
    return data.json()

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/meteostations?output_epsg=28992&page_size=25&page_offset=0"
getData(url)
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [95931.093, 497826.967]},
#    'properties': {'meteostationid': 209,
#     'name': 'IJMOND',
#     'lon': 4.518,
#     'lat': 52.465,
#     'alt': 0.0}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [89519.113, 465192.842]},
#    'properties': {'meteostationid': 210,
#     'name': 'Valkenburg',
#     'wmocode': 62100,
#     'lon': 4.43,
#     'lat': 52.171,
#     'alt': -0.2,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [89954.248, 461848.937]},
#    'properties': {'meteostationid': 215,
#     'name': 'VOORSCHOTEN',
#     'lon': 4.437,
#     'lat': 52.141,
#     'alt': -1.1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98442.881, 497574.905]},
#    'properties': {'meteostationid': 225,
#     'name': 'IJMUIDEN',
#     'lon': 4.555,
#     'lat': 52.463,
#     'alt': 4.4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [114369.94, 549161.998]},
#    'properties': {'meteostationid': 235,
#     'name': 'De Kooy',
#     'wmocode': 62350,
#     'lon': 4.783,
#     'lat': 52.928,
#     'alt': 0.57,
#     'source': 'KONINKLIJKNEDERLANDSMETEOROLOGISCHINSTITUUT(KNMI)(http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [114280.346, 481284.207]},
#    'properties': {'meteostationid': 240,
#     'name': 'Schiphol',
#     'wmocode': 62400,
#     'lon': 4.79,
#     'lat': 52.318,
#     'alt': -4.18,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [123157.252, 472651.583]},
#    'properties': {'meteostationid': 242,
#     'name': 'Vlieland',
#     'wmocode': 62420,
#     'lon': 4.921,
#     'lat': 52.241,
#     'alt': 1.72,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [140566.294, 516298.261]},
#    'properties': {'meteostationid': 248,
#     'name': 'WIJDENES',
#     'lon': 5.174,
#     'lat': 52.634,
#     'alt': 0.8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [127371.415, 517467.649]},
#    'properties': {'meteostationid': 249,
#     'name': 'Berkhout',
#     'wmocode': 62490,
#     'lon': 4.979,
#     'lat': 52.644,
#     'alt': -2.4,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [152195.188, 489350.894]},
#    'properties': {'meteostationid': 251,
#     'name': 'Hoorn Terschelling',
#     'wmocode': 62510,
#     'lon': 5.346,
#     'lat': 52.392,
#     'alt': 0.73,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [101756.715, 502322.805]},
#    'properties': {'meteostationid': 257,
#     'name': 'Wijk aan Zee',
#     'wmocode': 62570,
#     'lon': 4.603,
#     'lat': 52.506,
#     'alt': 8.5,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [155933.561, 517946.183]},
#    'properties': {'meteostationid': 258,
#     'name': 'HOUTRIBDIJK',
#     'lon': 5.401,
#     'lat': 52.649,
#     'alt': 7.3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [140802.698, 456881.772]},
#    'properties': {'meteostationid': 260,
#     'name': 'De Bilt',
#     'wmocode': 62600,
#     'lon': 5.18,
#     'lat': 52.1,
#     'alt': 2.0,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [147248.65, 460205.356]},
#    'properties': {'meteostationid': 265,
#     'name': 'Soesterberg',
#     'wmocode': 62650,
#     'lon': 5.274,
#     'lat': 52.13,
#     'alt': 14.0,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [154784.242, 545653.648]},
#    'properties': {'meteostationid': 267,
#     'name': 'Stavoren',
#     'wmocode': 62670,
#     'lon': 5.384,
#     'lat': 52.898,
#     'alt': -1.3,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [164026.007, 496701.962]},
#    'properties': {'meteostationid': 269,
#     'name': 'Lelystad',
#     'wmocode': 62690,
#     'lon': 5.52,
#     'lat': 52.458,
#     'alt': -4.41,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [179925.948, 470720.589]},
#    'properties': {'meteostationid': 270,
#     'name': 'Leeuwarden',
#     'wmocode': 62700,
#     'lon': 5.752,
#     'lat': 52.224,
#     'alt': 0.27,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [188849.762, 524072.138]},
#    'properties': {'meteostationid': 273,
#     'name': 'Marknesse',
#     'wmocode': 62730,
#     'lon': 5.888,
#     'lat': 52.703,
#     'alt': -3.35,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [188318.791, 452077.691]},
#    'properties': {'meteostationid': 275,
#     'name': 'Deelen',
#     'wmocode': 62750,
#     'lon': 5.873,
#     'lat': 52.056,
#     'alt': 45.23,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [210300.544, 491997.103]},
#    'properties': {'meteostationid': 277,
#     'name': 'Lauwersoog',
#     'wmocode': 62770,
#     'lon': 6.2,
#     'lat': 52.413,
#     'alt': 2.9,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [214285.151, 494491.524]},
#    'properties': {'meteostationid': 278,
#     'name': 'Heino',
#     'wmocode': 62780,
#     'lon': 6.259,
#     'lat': 52.435,
#     'alt': 3.6,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [235129.986, 529842.878]},
#    'properties': {'meteostationid': 279,
#     'name': 'Hoogeveen',
#     'wmocode': 62790,
#     'lon': 6.574,
#     'lat': 52.75,
#     'alt': 15.82,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [235179.97, 571581.223]},
#    'properties': {'meteostationid': 280,
#     'name': 'Eelde',
#     'wmocode': 62800,
#     'lon': 6.585,
#     'lat': 53.125,
#     'alt': 3.23,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [242062.157, 454174.134]},
#    'properties': {'meteostationid': 283,
#     'name': 'Hupsel',
#     'wmocode': 62830,
#     'lon': 6.657,
#     'lat': 52.069,
#     'alt': 29.7,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [222025.617, 621469.62]},
#    'properties': {'meteostationid': 285,
#     'name': 'HUIBERTGAT',
#     'lon': 6.399,
#     'lat': 53.575,
#     'alt': 0.0}}]}

# %%
data = getData(url)

# %%
def table_data_1(data):
    df = pd.DataFrame(columns=['coordinates','meteostationid','name','wmocode','longitude','latitude','altitude','source','provider'])
    for element in data['features']:
        coordinates = element['geometry'].get('coordinates')
        meteostationid = element['properties'].get('meteostationid')
        name = element['properties'].get('name')
        wmocode = element['properties'].get('wmocode',np.nan)
        longitude= element['properties'].get('lon')
        latitude = element['properties'].get('lat')
        altitude = element['properties'].get('alt',np.nan)
        source = element['properties'].get('source',np.nan)
        provider = element['properties'].get('provider',np.nan)
        s=pd.Series([coordinates,meteostationid,name,wmocode,longitude,latitude,altitude,source,provider],df.columns)
        df = df.append(s, ignore_index=True)
    return df

# %%
table_data_1(data)
# Out:
#                  coordinates meteostationid                name  wmocode  \
# 0    [95931.093, 497826.967]            209              IJMOND      NaN
# 1    [89519.113, 465192.842]            210          Valkenburg  62100.0
# 2    [89954.248, 461848.937]            215         VOORSCHOTEN      NaN
# 3    [98442.881, 497574.905]            225            IJMUIDEN      NaN
# 4    [114369.94, 549161.998]            235             De Kooy  62350.0
# 5   [114280.346, 481284.207]            240            Schiphol  62400.0
# 6   [123157.252, 472651.583]            242            Vlieland  62420.0
# 7   [140566.294, 516298.261]            248            WIJDENES      NaN
# 8   [127371.415, 517467.649]            249            Berkhout  62490.0
# 9   [152195.188, 489350.894]            251  Hoorn Terschelling  62510.0
# 10  [101756.715, 502322.805]            257        Wijk aan Zee  62570.0
# 11  [155933.561, 517946.183]            258         HOUTRIBDIJK      NaN
# 12  [140802.698, 456881.772]            260             De Bilt  62600.0
# 13   [147248.65, 460205.356]            265         Soesterberg  62650.0
# 14  [154784.242, 545653.648]            267            Stavoren  62670.0
# 15  [164026.007, 496701.962]            269            Lelystad  62690.0
# 16  [179925.948, 470720.589]            270          Leeuwarden  62700.0
# 17  [188849.762, 524072.138]            273           Marknesse  62730.0
# 18  [188318.791, 452077.691]            275              Deelen  62750.0
# 19  [210300.544, 491997.103]            277          Lauwersoog  62770.0
# 20  [214285.151, 494491.524]            278               Heino  62780.0
# 21  [235129.986, 529842.878]            279           Hoogeveen  62790.0
# 22   [235179.97, 571581.223]            280               Eelde  62800.0
# 23  [242062.157, 454174.134]            283              Hupsel  62830.0
# 24   [222025.617, 621469.62]            285          HUIBERTGAT      NaN
#
#     longitude  latitude  altitude  \
# 0       4.518    52.465      0.00
# 1       4.430    52.171     -0.20
# 2       4.437    52.141     -1.10
# 3       4.555    52.463      4.40
# 4       4.783    52.928      0.57
# 5       4.790    52.318     -4.18
# 6       4.921    52.241      1.72
# 7       5.174    52.634      0.80
# 8       4.979    52.644     -2.40
# 9       5.346    52.392      0.73
# 10      4.603    52.506      8.50
# 11      5.401    52.649      7.30
# 12      5.180    52.100      2.00
# 13      5.274    52.130     14.00
# 14      5.384    52.898     -1.30
# 15      5.520    52.458     -4.41
# 16      5.752    52.224      0.27
# 17      5.888    52.703     -3.35
# 18      5.873    52.056     45.23
# 19      6.200    52.413      2.90
# 20      6.259    52.435      3.60
# 21      6.574    52.750     15.82
# 22      6.585    53.125      3.23
# 23      6.657    52.069     29.70
# 24      6.399    53.575      0.00
#
#                                                source    provider
# 0                                                 NaN         NaN
# 1   KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4   KONINKLIJKNEDERLANDSMETEOROLOGISCHINSTITUUT(KN...  KNMI_DAILY
# 5   KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 6   KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 7                                                 NaN         NaN
# 8   KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 9   KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...         NaN
# 10  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 11                                                NaN         NaN
# 12  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 13  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 14  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 15  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 16  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 17  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 18  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 19  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 20  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 21  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 22  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 23  KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT...  KNMI_DAILY
# 24                                                NaN         NaN

# %% [markdown]
# **_Second request Return the data for the given meteostation._**

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/meteostations/265?output_epsg=28992&page_size=25&page_offset=0"
getData(url)
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [147248.65, 460205.356]},
#    'properties': {'meteostationid': 265,
#     'name': 'Soesterberg',
#     'wmocode': 62650,
#     'lon': 5.274,
#     'lat': 52.13,
#     'alt': 14.0,
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'provider': 'KNMI_DAILY'}}]}
