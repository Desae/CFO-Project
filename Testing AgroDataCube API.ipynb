# %%
import requests

#url = http://agrodatacube.wur.nl/api/v1/rest/fields?epsg=28992&year={0}&geometry=POINT(200000 500000)&page_size=1000&page_offset=0
#"http://agrodatacube.wur.nl/api/v1/rest/codes/cropcodes?page_size=25&page_offset=0"
#"https://agrodatacube.wur.nl/api/v1/rest/soiltypes/:entityid?output_epsg=28992&page_size=25&page_offset=0"
#"http://agrodatacube.wur.nl/api/v1/rest/sources"

headers = {
    #'Accept': "application/json",
    #Aseda's access token
    'token': "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3N1ZWR0byI6ImFzZWRhLm9hZEBnbWFpbC5jb20iLCJyZXNvdXJjZSI6WyIqIl0sInJlcXVlc3RfbGltaXQiOjI1MDAwLCJhcmVhX2xpbWl0IjoxLjBFOCwiZXhwIjoxNTQ4ODg5MjAwLCJpYXQiOjE1Mzg1ODY4NzAsImlzc3VlZGRhdGUiOjE1Mzg1ODY4NzB9.x6R7G35nCpwLbBwQ6XHuuJkn-37WIpaxNvDhEu4nTr4"
    }

# %%
#year to retrieve
year = 2016

# %%
# read field at a specific point and for a specific year (2016)
fields_url = "http://agrodatacube.wur.nl/api/v1/rest/fields?epsg=28992&year={0}&geometry=POINT(200000 500000)&page_size=1000&page_offset=0".format(year)

# %%
fields_data = requests.get(fields_url, headers=headers)

# %%
fields = fields_data.json()

# %%
fields
# Out:
# {'features': [{'geometry': {'coordinates': [200000, 500000], 'type': 'Point'},
#    'properties': {'area': 0.0,
#     'crop_code': '265',
#     'crop_name': 'Grasland, blijvend',
#     'fieldid': 5882883,
#     'perimeter': 0.0,
#     'year': 2016},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
len(fields['features'])
# Out:
# 1

# %%
src_url = "http://agrodatacube.wur.nl/api/v1/rest/sources"
src_data = requests.get(src_url, headers=headers)

# %%
src = src_data.json()
src
# Out:
# {'Please see the information at ': 'https://documenter.getpostman.com/view/3862510/RVnSHh76'}

# %%
import geojson

# %%
src_url = "http://agrodatacube.wur.nl/api/v1/rest/fields?year=2017&page_size=3"
src_data = requests.get(src_url, headers=headers)
#src = src_data.json()
# Out:
# {"features": [{"geometry": {"coordinates": [[[[102741.295, 496369.375], [102779.153, 496278.624], [103040.939, 496301.35], [103218.346, 496281.855], [103313.874, 495888.049], [103118.92, 495880.251], [102964.907, 495882.201], [102892.774, 495856.857], [102820.017, 495816.421], [102797.476, 495702.594], [102871.324, 495599.526], [103001.943, 495648.264], [103046.759, 495642.986], [103224.19, 495650.214], [103263.181, 495611.223], [103239.043, 495547.293], [103259.282, 495523.494], [103311.919, 495480.605], [103345.061, 495449.412], [103362.607, 495392.876], [103308.02, 495392.876], [103276.827, 495351.936], [103251.483, 495283.702], [103292.423, 495240.812], [103377.369, 495102.145], [103409.396, 495125.79], [103461.929, 495027.308], [103499.078, 494975.671], [103539.283, 494900.733], [103514.675, 494876.245], [103477.634, 494772.92], [103428.895, 494788.516], [103419.025, 494744.144], [103456.189, 494710.534], [103456.189, 494675.443], [103407.451, 494615.007], [103356.763, 494564.32
# ...

# %%
src = geojson.loads(src_data.content)
src
# Out:
# {"features": [{"geometry": {"coordinates": [[[[102741.295, 496369.375], [102779.153, 496278.624], [103040.939, 496301.35], [103218.346, 496281.855], [103313.874, 495888.049], [103118.92, 495880.251], [102964.907, 495882.201], [102892.774, 495856.857], [102820.017, 495816.421], [102797.476, 495702.594], [102871.324, 495599.526], [103001.943, 495648.264], [103046.759, 495642.986], [103224.19, 495650.214], [103263.181, 495611.223], [103239.043, 495547.293], [103259.282, 495523.494], [103311.919, 495480.605], [103345.061, 495449.412], [103362.607, 495392.876], [103308.02, 495392.876], [103276.827, 495351.936], [103251.483, 495283.702], [103292.423, 495240.812], [103377.369, 495102.145], [103409.396, 495125.79], [103461.929, 495027.308], [103499.078, 494975.671], [103539.283, 494900.733], [103514.675, 494876.245], [103477.634, 494772.92], [103428.895, 494788.516], [103419.025, 494744.144], [103456.189, 494710.534], [103456.189, 494675.443], [103407.451, 494615.007], [103356.763, 494564.32
# ...

# %%
import numpy as np

# %%
fields = src_data.json()
x = fields['features'][0]['geometry']['coordinates']

# %%
src
# Out:
# {'features': [{'geometry': {'coordinates': [[[[102741.295, 496369.375],
#        [102779.153, 496278.624],
#        [103040.939, 496301.35],
#        [103218.346, 496281.855],
#        [103313.874, 495888.049],
#        [103118.92, 495880.251],
#        [102964.907, 495882.201],
#        [102892.774, 495856.857],
#        [102820.017, 495816.421],
#        [102797.476, 495702.594],
#        [102871.324, 495599.526],
#        [103001.943, 495648.264],
#        [103046.759, 495642.986],
#        [103224.19, 495650.214],
#        [103263.181, 495611.223],
#        [103239.043, 495547.293],
#        [103259.282, 495523.494],
#        [103311.919, 495480.605],
#        [103345.061, 495449.412],
#        [103362.607, 495392.876],
#        [103308.02, 495392.876],
#        [103276.827, 495351.936],
#        [103251.483, 495283.702],
#        [103292.423, 495240.812],
#        [103377.369, 495102.145],
#        [103409.396, 495125.79],
#        [103461.929, 495027.308],
# ...

# %%
x = np.array(x)
x.shape
# Out:
# (1, 9)

# %%
x.ndim
# Out:
# 2

# %%
for i in range(len(src['features'])):
    year = src['features'][i]['properties']['year']
    fieldId = src['features'][i]['properties']['fieldid']
    cropName = src['features'][i]['properties']['crop_name']    
    print("year:", year, "fieldId:", fieldId, "crop:", cropName)
# Out:
# year: 2017 fieldId: 6900922 crop: Natuurterreinen (incl. heide)
# year: 2017 fieldId: 6729347 crop: Natuurterreinen (incl. heide)
# year: 2017 fieldId: 6708841 crop: Natuurterreinen (incl. heide)

# %%
len(src['features'])
# Out:
# 3

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/sources/Grasland, blijvend"
n = requests.get(url,headers=headers)

# %%
n.status_code
# Out:
# 404

# %%
url2 = "http://agrodatacube.wur.nl/api/v1/rest/soiltypes?entityid=2&page_size=25"
m = requests.get(url2,headers=headers)

# %%
m.status_code
# Out:
# 200

# %%
m.json()
# Out:
# {'features': [{'geometry': {'coordinates': [[[[251329, 442994],
#        [251334, 442969],
#        [251329, 442931],
#        [251314, 442918],
#        [251283.016, 442910],
#        [251227.016, 442915],
#        [251176, 442913],
#        [251113.016, 442915],
#        [251077, 442920],
#        [251052, 442918],
#        [251042.016, 442898],
#        [251034, 442875],
#        [251006, 442862],
#        [250872, 442862],
#        [250793, 442870],
#        [250742.016, 442867],
#        [250681, 442875],
#        [250643.016, 442875],
#        [250620, 442857],
#        [250607, 442829],
#        [250564, 442809],
#        [250521, 442819],
#        [250498, 442819],
#        [250470, 442814],
#        [250425, 442793],
#        [250386, 442778],
#        [250361, 442786],
#        [250351, 442804],
#        [250341, 442832],
#        [250323, 442849],
#        [250287, 442892],
#        [250267, 442923],
#        [250275, 442941],
#        [250303, 442953],
# ...

# %%
field_url = "http://agrodatacube.wur.nl/api/v1/rest/fields?geometry=POLYGON%20((4.2%2052,%204.2%2053,%204.3%2053,%204.3%2052,%204.2%2052))&epsg=4326&year=2017&cropname=mais&output_epsg=4326"
fields = requests.get(field_url, headers=headers)

# %%
fields.json()
# Out:
# {'features': [{'geometry': {'coordinates': [[[4.3, 52.0003971],
#       [4.2999527, 52.0003892],
#       [4.2998019, 52.0003331],
#       [4.2997424, 52.0003243],
#       [4.2996703, 52.0003569],
#       [4.2995412, 52.0004366],
#       [4.299071, 52.0006784],
#       [4.2989127, 52.000772],
#       [4.2987999, 52.000897],
#       [4.2987376, 52.0009214],
#       [4.2985279, 52.0009885],
#       [4.298438, 52.00104],
#       [4.2982988, 52.0011421],
#       [4.2982414, 52.0012046],
#       [4.2982117, 52.0015528],
#       [4.2981933, 52.0016787],
#       [4.2981631, 52.0017283],
#       [4.2980387, 52.0018532],
#       [4.2979471, 52.0018976],
#       [4.2977996, 52.0019438],
#       [4.2977094, 52.0020071],
#       [4.2975729, 52.0021533],
#       [4.2974645, 52.0022546],
#       [4.297367, 52.0023001],
#       [4.2971358, 52.0023812],
#       [4.2969699, 52.0024676],
#       [4.2968853, 52.0025418],
#       [4.2968047, 52.0026052],
#       [4.29667, 52.0026801],
# ...

# %%
soil_url = "http://agrodatacube.wur.nl/api/v1/rest/codes/soilcodes?page_size=25&page_offset=0"
soil_codes = requests.get(soil_url, headers=headers)

# %%
soil_codes.json()
# Out:
# {'features': [{'geometry': None,
#    'properties': {'soilcode': 'AAKp',
#     'soilname': 'Lichte zavel',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'AAP',
#     'soilname': 'Zand',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'ABk',
#     'soilname': 'Lichte zavel',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'ABkt',
#     'soilname': 'Lichte zavel',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'ABl',
#     'soilname': 'Leem',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'ABv',
#     'soilname': 'Zand',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'ABvg',
# ...

# %%
entity_url = "http://agrodatacube.wur.nl/api/v1/rest/soiltypes/?ABk&output_epsg=28992&page_size=25&page_offset=0"
entity = requests.get(entity_url,headers=headers)

# %%
entity.json()
# Out:
# {'features': [{'geometry': {'coordinates': [[[[251329, 442994],
#        [251334, 442969],
#        [251329, 442931],
#        [251314, 442918],
#        [251283.016, 442910],
#        [251227.016, 442915],
#        [251176, 442913],
#        [251113.016, 442915],
#        [251077, 442920],
#        [251052, 442918],
#        [251042.016, 442898],
#        [251034, 442875],
#        [251006, 442862],
#        [250872, 442862],
#        [250793, 442870],
#        [250742.016, 442867],
#        [250681, 442875],
#        [250643.016, 442875],
#        [250620, 442857],
#        [250607, 442829],
#        [250564, 442809],
#        [250521, 442819],
#        [250498, 442819],
#        [250470, 442814],
#        [250425, 442793],
#        [250386, 442778],
#        [250361, 442786],
#        [250351, 442804],
#        [250341, 442832],
#        [250323, 442849],
#        [250287, 442892],
#        [250267, 442923],
#        [250275, 442941],
#        [250303, 442953],
# ...

# %%
entity_url = "http://agrodatacube.wur.nl/api/v1/rest/soiltypes?output_epsg=28992&page_size=25&page_offset=0"
entity = requests.get(entity_url,headers=headers)

# %%
entity.json()
# Out:
# {'features': [{'geometry': {'coordinates': [[[[251329, 442994],
#        [251334, 442969],
#        [251329, 442931],
#        [251314, 442918],
#        [251283.016, 442910],
#        [251227.016, 442915],
#        [251176, 442913],
#        [251113.016, 442915],
#        [251077, 442920],
#        [251052, 442918],
#        [251042.016, 442898],
#        [251034, 442875],
#        [251006, 442862],
#        [250872, 442862],
#        [250793, 442870],
#        [250742.016, 442867],
#        [250681, 442875],
#        [250643.016, 442875],
#        [250620, 442857],
#        [250607, 442829],
#        [250564, 442809],
#        [250521, 442819],
#        [250498, 442819],
#        [250470, 442814],
#        [250425, 442793],
#        [250386, 442778],
#        [250361, 442786],
#        [250351, 442804],
#        [250341, 442832],
#        [250323, 442849],
#        [250287, 442892],
#        [250267, 442923],
#        [250275, 442941],
#        [250303, 442953],
# ...

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/codes/cropcodes/2645?page_size=25&page_offset=0"

soil_code = requests.get(url,headers=headers)

# %%
soil_code.json()
# Out:
# {'features': [{'geometry': None,
#    'properties': {'cropcode': '2645',
#     'cropid': 2,
#     'cropname': 'Notenbomen',
#     'grondgebruik': 'Bouwland'},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/codes/cropcodes?page_size=25&page_offset=0"
entity = requests.get(url,headers=headers)
entity
# Out:
# <Response [200]>

# %%
entity.json()
# Out:
# {'features': [{'geometry': None,
#    'properties': {'cropcode': '2645',
#     'cropid': 2,
#     'cropname': 'Notenbomen',
#     'grondgebruik': 'Bouwland'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'cropcode': '1908',
#     'cropid': 3,
#     'cropname': 'Braak, zwarte- met ontheffing',
#     'grondgebruik': 'Braakland'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'cropcode': '3718',
#     'cropid': 4,
#     'cropname': 'Grasland, natuurlijk',
#     'grondgebruik': 'Grasland'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'cropcode': '859',
#     'cropid': 5,
#     'cropname': 'Aardappelen, zetmeel geleverd aan buitenland',
#     'grondgebruik': 'Bouwland'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'cropcode': '3792',
#     'cropid': 6,
#     'cropname': 'Aardappelen, consumptie op zand/veengrond',
#     'grondgebruik': 'Bouwland'},
#    'type': 'Feature'},
#   {'geometry': None,
# ...

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/codes/cropcodes?page_size=25&page_offset=0"
data  = requests.get(url, headers=headers)

# %%
crop_code = data.json()

# %%
crop_code
# Out:
# {'features': [{'geometry': None,
#    'properties': {'cropcode': '2645',
#     'cropid': 2,
#     'cropname': 'Notenbomen',
#     'grondgebruik': 'Bouwland'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'cropcode': '1908',
#     'cropid': 3,
#     'cropname': 'Braak, zwarte- met ontheffing',
#     'grondgebruik': 'Braakland'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'cropcode': '3718',
#     'cropid': 4,
#     'cropname': 'Grasland, natuurlijk',
#     'grondgebruik': 'Grasland'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'cropcode': '859',
#     'cropid': 5,
#     'cropname': 'Aardappelen, zetmeel geleverd aan buitenland',
#     'grondgebruik': 'Bouwland'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'cropcode': '3792',
#     'cropid': 6,
#     'cropname': 'Aardappelen, consumptie op zand/veengrond',
#     'grondgebruik': 'Bouwland'},
#    'type': 'Feature'},
#   {'geometry': None,
# ...

# %%
crop_code['features'][0]
# Out:
# {'geometry': None,
#  'properties': {'cropcode': '2645',
#   'cropid': 2,
#   'cropname': 'Notenbomen',
#   'grondgebruik': 'Bouwland'},
#  'type': 'Feature'}

# %%
url="http://agrodatacube.wur.nl/api/v1/rest/codes/cropcodes/2645?page_size=25&page_offset=0"
data  = requests.get(url, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': None,
#    'properties': {'cropcode': '2645',
#     'cropid': 2,
#     'cropname': 'Notenbomen',
#     'grondgebruik': 'Bouwland'},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
soil_codes ="http://agrodatacube.wur.nl/api/v1/rest/codes/soilcodes?page_size=25&page_offset=0"
data = requests.get(soil_codes, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': None,
#    'properties': {'soilcode': 'AAKp',
#     'soilname': 'Lichte zavel',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'AAP',
#     'soilname': 'Zand',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'ABk',
#     'soilname': 'Lichte zavel',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'ABkt',
#     'soilname': 'Lichte zavel',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'ABl',
#     'soilname': 'Leem',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'ABv',
#     'soilname': 'Zand',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'soilcode': 'ABvg',
# ...

# %%
spec_soil_code = "http://agrodatacube.wur.nl/api/v1/rest/codes/soilcodes/AAP?page_size=25&page_offset=0"
data = requests.get(spec_soil_code, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': None,
#    'properties': {'soilcode': 'AAP',
#     'soilname': 'Zand',
#     'soiltype': 'Associaties'},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
field_stuff = 'http://agrodatacube.wur.nl/api/v1/rest/fields?output_epsg=28992&page_size=25&page_offset=0&year=2017'
data = requests.get(field_stuff, headers=headers)

# %%
data.json()["features"][-1]
# Out:
# {'geometry': {'coordinates': [[[[68776.865, 372304.916],
#      [68744.419, 372306.039],
#      [68727.675, 372309.018],
#      [68715.118, 372314.039],
#      [68690.39, 372327.419],
#      [68677.463, 372333.076],
#      [68640.047, 372356.776],
#      [68626.143, 372370.65],
#      [68622.639, 372386.705],
#      [68618.278, 372395.444],
#      [68618.927, 372400.246],
#      [68635.511, 372406.221],
#      [68645.141, 372407.528],
#      [68649.177, 372405.548],
#      [68658.638, 372401.815],
#      [68677.383, 372400.131],
#      [68685.225, 372402.201],
#      [68699.335, 372409.162],
#      [68704.955, 372415.053],
#      [68709.274, 372423.858],
#      [68713.075, 372434.623],
#      [68711.416, 372448.408],
#      [68708.005, 372458.388],
#      [68689.885, 372485.935],
#      [68678.062, 372508.46],
#      [68671.238, 372540.48],
#      [68670.101, 372551.848],
#      [68670.024, 372579.762],
#      [68672.448, 372591.431],
#      [68675.849, 372600.686],
# ...

# %%
ahn_zonal_statistics="http://agrodatacube.wur.nl/api/v1/rest/fields/6952729/ahn?page_size=25&page_offset=0"
data = requests.get(ahn_zonal_statistics, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': None,
#    'properties': {'area': 2226306.3308251156,
#     'max': 300.0,
#     'mean': 207.385,
#     'min': -27.0},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
meteo_stats = "http://agrodatacube.wur.nl/api/v1/rest/fields/6952729/meteostations?output_epsg=28992&page_size=50&page_offset=0"

data = requests.get(meteo_stats,headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': None,
#    'properties': {'distance': 26963.03149753652,
#     'fieldid': 6952729,
#     'meteostationid': 323,
#     'rank': 5},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'distance': 22841.201256895758,
#     'fieldid': 6952729,
#     'meteostationid': 319,
#     'rank': 4},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'distance': 16975.30293952113,
#     'fieldid': 6952729,
#     'meteostationid': 340,
#     'rank': 3},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'distance': 15054.953172110758,
#     'fieldid': 6952729,
#     'meteostationid': 315,
#     'rank': 2},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'distance': 14812.843564105797,
#     'fieldid': 6952729,
#     'meteostationid': 331,
#     'rank': 1},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/fields/6952729/ndvi?output_epsg=28992&page_size=25&page_offset=0"

data = requests.get(url,headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': None,
#    'properties': {'distance': 26963.03149753652,
#     'fieldid': 6952729,
#     'meteostationid': 323,
#     'rank': 5},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'distance': 22841.201256895758,
#     'fieldid': 6952729,
#     'meteostationid': 319,
#     'rank': 4},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'distance': 16975.30293952113,
#     'fieldid': 6952729,
#     'meteostationid': 340,
#     'rank': 3},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'distance': 15054.953172110758,
#     'fieldid': 6952729,
#     'meteostationid': 315,
#     'rank': 2},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'distance': 14812.843564105797,
#     'fieldid': 6952729,
#     'meteostationid': 331,
#     'rank': 1},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/fields/6952729/soilparams?output_epsg=28992&page_size=25&page_offset=0"
data = requests.get(url,headers=headers)

# %%
data.json()["features"][0]
# Out:
# {'geometry': {'coordinates': [[[[69218.837, 372420.269],
#      [69175, 372403],
#      [69152, 372388],
#      [69127, 372375],
#      [69081, 372375],
#      [69048, 372388],
#      [69015, 372393],
#      [68967, 372403],
#      [68921, 372408],
#      [68880, 372403],
#      [68850, 372416],
#      [68827, 372444],
#      [68827, 372453.73],
#      [68831.334, 372472.816],
#      [68837.053, 372489.581],
#      [68841.588, 372499.987],
#      [68849.961, 372510.331],
#      [68865.285, 372525.799],
#      [68872.445, 372530.12],
#      [68891.088, 372536.396],
#      [68931.681, 372543.145],
#      [68937.678, 372542.757],
#      [68948.056, 372539.182],
#      [68953.478, 372534.691],
#      [68960.176, 372525.966],
#      [68967.094, 372518.82],
#      [68974.454, 372514.83],
#      [68983.535, 372507.961],
#      [68992.971, 372502.715],
#      [69001.184, 372499.765],
#      [69008.235, 372493.565],
#      [69016.964, 372483.72],
#      [69033.545, 372456.363],
# ...

# %%
meteodata_url = "http://agrodatacube.wur.nl/api/v1/rest/meteodata?fromdate=2016&todate=2016&page_size=1000"
data = requests.get(meteodata_url, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': {'coordinates': [89519.1134373616,
#      465192.842499937],
#     'type': 'Point'},
#    'properties': {'datum': '2016-01-01',
#     'global_radiation': 300.0,
#     'max_humidity': 100.0,
#     'max_temperature': 8.3,
#     'mean_humidity': 91.0,
#     'mean_sea_level_pressure': 1021.2,
#     'mean_temperature': 5.6,
#     'meteostationid': 210,
#     'min_temperature': 1.1,
#     'potential_evapotranspiration': 0.4,
#     'precipitation': 1.1,
#     'sunshine_duration': 4.1},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [89519.1134373616, 465192.842499937],
#     'type': 'Point'},
#    'properties': {'datum': '2016-01-02',
#     'global_radiation': 98.0,
#     'max_humidity': 98.0,
#     'max_temperature': 7.2,
#     'mean_humidity': 92.0,
#     'mean_sea_level_pressure': 1007.5,
#     'mean_temperature': 6.2,
#     'meteostationid': 210,
#     'min_temperature': 4.9,
#     'potential_evapotranspiration': 0.1,
#     'precipitation': 5.6,
# ...

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/meteodata/210/2016?page_size=25&page_offset=0"
data = requests.get(url, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': None,
#    'properties': {'datum': '2016-01-01',
#     'global_radiation': 300.0,
#     'max_humidity': 100.0,
#     'max_temperature': 8.3,
#     'mean_humidity': 91.0,
#     'mean_sea_level_pressure': 1021.2,
#     'mean_temperature': 5.6,
#     'meteostationid': 210,
#     'min_temperature': 1.1,
#     'potential_evapotranspiration': 0.4,
#     'precipitation': 1.1,
#     'sunshine_duration': 4.1},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'datum': '2016-01-02',
#     'global_radiation': 98.0,
#     'max_humidity': 98.0,
#     'max_temperature': 7.2,
#     'mean_humidity': 92.0,
#     'mean_sea_level_pressure': 1007.5,
#     'mean_temperature': 6.2,
#     'meteostationid': 210,
#     'min_temperature': 4.9,
#     'potential_evapotranspiration': 0.1,
#     'precipitation': 5.6,
#     'sunshine_duration': 0.2},
#    'type': 'Feature'},
#   {'geometry': None,
#    'properties': {'datum': '2016-01-03',
# ...

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/meteostations?output_epsg=28992&page_size=25&page_offset=0"
data = requests.get(url, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': {'coordinates': [95931.093, 497826.967],
#     'type': 'Point'},
#    'properties': {'alt': 0.0,
#     'lat': 52.465,
#     'lon': 4.518,
#     'meteostationid': 209,
#     'name': 'IJMOND'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [89519.113, 465192.842], 'type': 'Point'},
#    'properties': {'alt': -0.2,
#     'lat': 52.171,
#     'lon': 4.43,
#     'meteostationid': 210,
#     'name': 'Valkenburg',
#     'provider': 'KNMI_DAILY',
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'wmocode': 62100},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [89954.248, 461848.937], 'type': 'Point'},
#    'properties': {'alt': -1.1,
#     'lat': 52.141,
#     'lon': 4.437,
#     'meteostationid': 215,
#     'name': 'VOORSCHOTEN'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [98442.881, 497574.905], 'type': 'Point'},
# ...

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/meteostations/265?output_epsg=28992&page_size=25&page_offset=0"
data = requests.get(url, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': {'coordinates': [147248.65, 460205.356],
#     'type': 'Point'},
#    'properties': {'alt': 14.0,
#     'lat': 52.13,
#     'lon': 5.274,
#     'meteostationid': 265,
#     'name': 'Soesterberg',
#     'provider': 'KNMI_DAILY',
#     'source': 'KONINKLIJK NEDERLANDS METEOROLOGISCH INSTITUUT (KNMI) (http://www.knmi.nl/klimatologie/metadata/debilt.html)',
#     'wmocode': 62650},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/meteostations/265?output_epsg=28992&page_size=25&page_offset=0"
data = requests.get(url, headers=headers)

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/regions/municipalities?page_size=25&page_offset=0&output_epsg=28992"
data = requests.get(url, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': {'coordinates': [[[[126208.656, 426198.88],
#        [125729, 426324.992],
#        [125201, 426440.992],
#        [124340, 426608.992],
#        [123901, 426731.008],
#        [123562, 426756.992],
#        [123269.304, 426733.312],
#        [123251.888, 426871.296],
#        [123243.192, 426980.544],
#        [123233.232, 427093.536],
#        [123221.648, 427201.952],
#        [123194.512, 427396.256],
#        [123172.904, 427560.352],
#        [123160.179, 427700.281],
#        [123136.173, 427899.33],
#        [123119.72, 428002.915],
#        [123117.375, 428011.663],
#        [123113.039, 428017.032],
#        [123091.431, 428029.234],
#        [123054.824, 428049.571],
#        [123019.742, 428064.062],
#        [122918.31, 428094.059],
#        [122933.817, 428130.412],
#        [123007.031, 428103.973],
#        [123079.483, 428081.348],
#        [123150.241, 428065.569],
#        [123193.6, 428051.456],
#        [123212.6, 428045.888],
# ...

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/regions/postalcodes?page_size=25&output_epsg=28992&page_offset=0"
data = requests.get(url, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': {'coordinates': [[[[122176.792, 487929.514],
#        [122180.323, 487928.252],
#        [122181.666, 487927.884],
#        [122246.232, 487910.177],
#        [122259.064, 487906.658],
#        [122259.532, 487908.287],
#        [122286.625, 487900.499],
#        [122262.668, 487804.67],
#        [122261.66, 487799.26],
#        [122204, 487810],
#        [122198.682, 487812.243],
#        [122144.412, 487835.127],
#        [122121, 487845],
#        [122119.098, 487846.157],
#        [122113.087, 487849.816],
#        [122114.63, 487852.192],
#        [122115.684, 487853.816],
#        [122117.552, 487856.692],
#        [122122.562, 487864.41],
#        [122123.27, 487865.501],
#        [122123.67, 487866.117],
#        [122129.411, 487874.959],
#        [122130.531, 487876.705],
#        [122132.706, 487880.094],
#        [122133.04, 487880.356],
#        [122138.297, 487884.478],
#        [122146.725, 487891.085],
#        [122158.907, 487900.636],
# ...

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/regions/provences?page_size=25&output_epsg=28992&page_offset=0"
data = requests.get(url, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': {'coordinates': [[[[98489.48, 480625.248],
#        [98834.792, 480459.52],
#        [99036.912, 480848.896],
#        [99059.88, 480872.128],
#        [99200.464, 481247.456],
#        [99202.768, 481251.392],
#        [99208.184, 481264.672],
#        [99238.784, 481251.872],
#        [99254.504, 481245.568],
#        [99462.232, 481164.064],
#        [99467.352, 481141.28],
#        [99496.64, 481131.104],
#        [99735.712, 481247.808],
#        [99753.512, 481252.928],
#        [100000, 481374.464],
#        [100081.272, 481412.32],
#        [100119.368, 481432.352],
#        [100178.888, 481460.192],
#        [100185.67, 481464.44],
#        [100666.87, 481397.04],
#        [100713.97, 481391.14],
#        [100786.97, 481396.34],
#        [100859.07, 481391.34],
#        [100913.87, 481382.94],
#        [100984.87, 481379.14],
#        [101000.67, 481378.44],
#        [101017.57, 481378.64],
#        [101030.87, 481380.74],
# ...

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/soilparams/401?page_size=25&page_offset=0"
data = requests.get(url, headers=headers)

# %%
data.json()["features"][0]
# Out:
# {'geometry': None,
#  'properties': {'a_waarde': 1,
#   'bodem_nr': 13040,
#   'cac03': 9.0,
#   'dichtheid': 1.030652597,
#   'eenheid': 'MOb75',
#   'end_depth': 10.0,
#   'gebruik': 'N',
#   'hor_code': '1Ahg',
#   'layer_nr': 1,
#   'leem': 75.0,
#   'leem_p10': 20.0,
#   'leem_p90': 90.0,
#   'lutum': 30.0,
#   'lutum_p10': 12.0,
#   'lutum_p90': 45.0,
#   'm50': 80.0,
#   'm50_p10': 70.0,
#   'm50_p90': 100.0,
#   'materiaal': 210.0,
#   'opp_aandeel': 28.0,
#   'orgstof': 10.0,
#   'orgstof_p10': 4.0,
#   'orgstof_p90': 20.0,
#   'ph_kcl': 7.8,
#   'ph_p10': 7.5,
#   'ph_p90': 8.0,
#   'silt': 45.0,
#   'soilparamid': 401,
#   'staring_bouwsteen': 'B10',
#   'start_depth': 0.0},
#  'type': 'Feature'}

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/soiltypes?page_size=1000&page_offset=1"
data = requests.get(url, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': {'coordinates': [[[[156510, 558677],
#        [156469, 558673],
#        [156414, 558682],
#        [156358, 558716],
#        [156321, 558728],
#        [156342, 558795],
#        [156375, 558902],
#        [156410, 558969],
#        [156491, 558968],
#        [156540, 558957],
#        [156572, 558931],
#        [156590, 558895],
#        [156590, 558813],
#        [156575, 558742],
#        [156547, 558697],
#        [156510, 558677]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'area': 60964.48954981311,
#     'entityid': 1001,
#     'perimeter': 921.447635059703,
#     'soilcode': '|f TERP',
#     'soilname': 'Zware zavel',
#     'soiltype': 'Dikke eerdgronden'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[162058, 559463],
#        [162016, 559457],
#        [161986, 559465],
#        [161965, 559480],
#        [161960, 559510],
#        [161973, 559544],
#        [161964, 559567],
#        [161945, 559594],
# ...

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/soiltypes/8?output_epsg=28992&page_size=25&page_offset=0"
data = requests.get(url, headers=headers)

# %%
data.json()
# Out:
# {'features': [{'geometry': {'coordinates': [[[[175889.031, 315421.438],
#        [175919.016, 315200.469],
#        [176367.016, 315214.438],
#        [176418.031, 315203.469],
#        [176475.016, 315166.469],
#        [176513.016, 315118.469],
#        [176528.016, 315073.469],
#        [176533.016, 315012.438],
#        [176528.016, 314940.469],
#        [176511.016, 314866.438],
#        [176474.031, 314804.438],
#        [176433.031, 314744.438],
#        [176398.031, 314718.438],
#        [176361.016, 314691.438],
#        [176346.031, 314647.438],
#        [176330.016, 314579.437],
#        [176289.016, 314466.438],
#        [176257.016, 314380.438],
#        [176226.031, 314328.438],
#        [176206.031, 314276.438],
#        [176192.016, 314211.438],
#        [176187.031, 314144.406],
#        [176135.031, 314110.406],
#        [176063.016, 314043.438],
#        [175990.016, 313981.406],
#        [175923.016, 313949.438],
#        [175848.016, 313943.406],
# ...

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/sources"
data = requests.get(url, headers=headers)

# %%
data.json()
# Out:
# {'Please see the information at ': 'https://documenter.getpostman.com/view/3862510/RVnSHh76'}

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/sources/meteostationid"
data = requests.get(url, headers=headers)

# %%
data
# Out:
# <Response [404]>

# %%
url = "http://agrodatacube.wur.nl/api/v1/rest/ahn?geometry=POLYGON(( 164685 451073, 184119 451073, 184119 433332, 164685 433332, 164685 451073 ))&epsg=28992"
data = requests.get(url,headers=headers)

# %%
data
# Out:
# <Response [500]>

# %%
# A simple test of modularizing the code
def getData(url):
    data = requests.get(url, headers=headers)
    return data.json()

# %%
getData("http://agrodatacube.wur.nl/api/v1/rest/soiltypes/8?output_epsg=28992&page_size=25&page_offset=0")
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[175889.031, 315421.438],
#        [175919.016, 315200.469],
#        [176367.016, 315214.438],
#        [176418.031, 315203.469],
#        [176475.016, 315166.469],
#        [176513.016, 315118.469],
#        [176528.016, 315073.469],
#        [176533.016, 315012.438],
#        [176528.016, 314940.469],
#        [176511.016, 314866.438],
#        [176474.031, 314804.438],
#        [176433.031, 314744.438],
#        [176398.031, 314718.438],
#        [176361.016, 314691.438],
#        [176346.031, 314647.438],
#        [176330.016, 314579.437],
#        [176289.016, 314466.438],
#        [176257.016, 314380.438],
#        [176226.031, 314328.438],
#        [176206.031, 314276.438],
#        [176192.016, 314211.438],
#        [176187.031, 314144.406],
#        [176135.031, 314110.406],
#        [176063.016, 314043.438],
#        [175990.016, 313981.406],
# ...
